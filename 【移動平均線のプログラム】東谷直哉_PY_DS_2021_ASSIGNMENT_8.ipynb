# %% [markdown]
# <a href="https://colab.research.google.com/github/higshitani/higshitani.github.io/blob/main/%E3%80%90%E7%A7%BB%E5%8B%95%E5%B9%B3%E5%9D%87%E7%B7%9A%E3%81%AE%E3%83%97%E3%83%AD%E3%82%B0%E3%83%A9%E3%83%A0%E3%80%91%E6%9D%B1%E8%B0%B7%E7%9B%B4%E5%93%89_PY_DS_2021_ASSIGNMENT_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# coding: utf-8
import numpy as np
import matplotlib.pyplot as plt

#取り込み
data = np.loadtxt('covid-19-patient.txt', skiprows=1)
#希望の配列をトレース
days = data[:,0]
patients = data[:,1]

#移動平均する幅と増減を表現するための差分を定義
delta = np.diff(patients,prepend=0)
num = 7 #一週間とした
num2 = 14 #2週間とした
arr = np.ones(num)/num
arr2 = np.ones(num2)/num2

#移動平均のための値を算出
y = np.convolve(patients, arr, mode = 'same')

#図を表現
plt.figure(figsize=(25,13)) #初期値は(6.4, 4.8)
plt.plot(days, y, '-', color=(0,1,0))
ｐｌｔ.bar(days, patients,0.7, align="center", color ="#ff7f00")
plt.scatter(days, patients, c=delta, cmap='bwr')
plt.xlabel('DAYS FROM JAN. 1, 2020')
plt.ylabel('NUMBER OF TEST-POSITIVE')
plt.xlim(0,700)
plt.ylim(0,30000)
plt.grid(True)
plt.colorbar()
plt.show()

# %%
# coding: utf-8
import numpy as np
import matplotlib.pyplot as plt

#取り込み
data = np.loadtxt('covid-19-patient.txt', skiprows=1)
#希望の配列をトレース
days = data[:,0]
patients = data[:,1]

#移動平均する幅と増減を表現するための差分を定義
delta = np.diff(patients,prepend=0)
num = 7 #一週間とした
num2 = 14 #2週間とした
arr = np.ones(num)/num
arr2 = np.ones(num2)/num2

#移動平均のための値を算出
y = np.convolve(patients, arr, mode = 'same')
y2 = np.convolve(patients, arr2, mode = 'same')

#図を表現
plt.figure(figsize=(25,13)) #初期値は(6.4, 4.8)
plt.plot(days, y, '-', color=(0,.8,0))
plt.plot(days, y2, '-', color=(0,.2,.2))
plt.scatter(days, patients, c=delta, cmap='bwr')
plt.xlabel('DAYS FROM JAN. 1, 2020')
plt.ylabel('NUMBER OF TEST-POSITIVE')
plt.xlim(0,700)
plt.ylim(0,30000)
plt.grid(True)
plt.colorbar()
plt.show()

# %%
# coding: utf-8
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt('covid-19-patient.txt', skiprows=1)
days = data[:,0]
patients = data[:,1]

delta = np.diff(patients,prepend=0)

plt.scatter(days, patients, c=delta, cmap='bwr')
plt.xlabel('DAYS FROM JAN. 1, 2020')
plt.ylabel('NUMBER OF TEST-POSITIVE')
plt.xlim(0,700)
plt.ylim(0,30000)
plt.grid(True)
plt.colorbar()
plt.show()

# %%
# coding: utf-8
import numpy as np
import matplotlib.pyplot as plt
data = np.loadtxt('covid-19-patient.txt', skiprows=1)
days = data[:,0]
patients = data[:,1]
delta = np.diff(patients,prepend=0)

pinc = np.ma.masked_where(delta<0, patients)
pdec = np.ma.masked_where(delta>=0, patients)

plt.plot(days, pdec, '-o', color=(0,0,1))
plt.plot(days, pinc, '-o', color=(1,0,0))
plt.xlabel('DAYS FROM JAN. 1, 2020')
plt.ylabel('NUMBER OF TEST-POSITIVE')
plt.xlim(0,700)
plt.ylim(0,30000)
plt.grid(True)
plt.show()

# %%
# coding: utf-8
import numpy as np
import matplotlib.pyplot as plt
data = np.loadtxt('covid-19-patient.txt', skiprows=1)
days = data[:,0]
patients = data[:,1]
num = 7

arr = np.ones(num)/num

y = np.convolve(patients, arr, mode = 'same')


plt.figure(figsize=(22,13)) #初期値は(6.4, 4.8)
plt.plot(days, patients, '-o', color=(0,0,1))
plt.plot(days, y, '-o', color=(0,1,0))
plt.xlabel('DAYS FROM JAN. 1, 2020')
plt.ylabel('NUMBER OF TEST-POSITIVE')
plt.xlim(0,700)
plt.ylim(0,30000)
plt.grid(True)
plt.show()

# %%
# coding: utf-8
import numpy as np
import matplotlib.pyplot as plt

#取り込み
data = np.loadtxt('covid-19-patient.txt', skiprows=1)
#希望の配列をトレース
days = data[:,0]
patients = data[:,1]

#移動平均する幅と増減を表現するための差分を定義
num = 7 #一週間とした
num2 = 14 #2週間とした
arr = np.ones(num)/num
arr2 = np.ones(num2)/num2

#移動平均のための値を算出
y = np.convolve(patients, arr, mode = 'same')
y2 = np.convolve(patients, arr2, mode = 'same')

#図を表現
plt.figure(figsize=(25,13)) #初期値は(6.4, 4.8)
plt.plot(days, y, '-', color=(0,.8,0))
plt.plot(days, y2, '-', color=(0,.2,.2))
ｐｌｔ.bar(days, patients)
plt.xlabel('DAYS FROM JAN. 1, 2020')
plt.ylabel('NUMBER OF TEST-POSITIVE')
plt.xlim(0,700)
plt.ylim(0,30000)
plt.grid(True)
plt.show()
